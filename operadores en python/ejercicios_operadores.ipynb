# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Ingresar peso: ")
peso = 60


print("Ingresar altura: ")
altura = 1.70
# Calcular el IMC (Índice de Masa Corporal)

BMI = peso * (altura ** 2)
print(BMI)
# Out:
# Ingresar peso:
# Ingresar altura:
# 173.39999999999998

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](attachment:image.png)

# %%
from  math import sqrt

x1 = 50
x2 = 60

y1 = 10
y2 = 30

distancia = sqrt((x2 - x1)**2 + (y2 -y1)**2)

print(distancia)
# Out:
# 22.360679774997898

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 612

xn0 = x % 10
# print(134 %10)

xn1 = x//10

xn2 = xn1 % 10
# print(xn2)

xn3 = x // 100	
# print(xn3)

print(xn0, xn2, xn3)
# Out:
# 2 1 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 230

y = (x // 24)

w = (x % 24) // 12

z = (x % 12) // 6

sobra = (x % 6) 

print(y)
print(w)
print(z)
print(sobra)
# Out:
# 9
# 1
# 0
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
seg = 230000

dias = seg // (60 * 60 * 24)

horas = seg % (60 * 60 * 24) // (60 * 60)

minutos = (seg % (60 * 60 * 24) ) % (60 * 60) // 60

s = (seg % (60 * 60 * 24) ) % (60 * 60) % 60

print(dias)
print(horas)
print(minutos)
print(s)
# Out:
# 2
# 15
# 53
# 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import pi, tan

s =  5

n = 3

area =  (n * s**2) / (4 * tan(pi/n))

print(area)
# Out:
# 10.825317547305486

# %% [markdown]
# Una variable se almacena en la memoria ram. Estas se pueden cambiar a medida que ejecutemos el programa.

# %% [markdown]
# Un programa esta compuesto por expresiones, las expresiones son variables, condicionales, operadores, llamdas a funciones.
