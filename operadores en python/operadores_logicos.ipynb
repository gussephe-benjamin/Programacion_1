# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ks = 130

monto = (ks <=100) * (ks * 0.4522) + (ks > 100) * ((100 * 0.4522) + (ks - 100)* 0.7)

print(monto)
# Out:
# 66.22

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 20

rpta = (num % 2 == 0) * ("par") or (num % 2 != 0)*("impar")

print(rpta)
# Out:
# par

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1 = 4

s2 = 7

s3 = 6

esTri = ((s1 + s2 > s3)*(s1 + s3 > s2)*(s2 + s3 > s1) * ("Es tri")) or ("No es tri")

print(esTri)
# Out:
# Es tri

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
monto = 100

calculo = monto + (monto * 0.05) + (monto * 0.18)

print(calculo)
# Out:
# 123.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
litro  = 14
mas_de_litro = 7

fin = litro * 1.25 + mas_de_litro * 3.75

print(fin)
# Out:
# 43.75

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 5432

a = num % 10

b = (num % 100) // 10

c = (num % 1000) // 100

d = num // 1000

print(d," + ",c," + ",b," + ",a, " = ", a+b+c+d)
# Out:
# 5  +  4  +  3  +  2  =  14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 1

b = 2

c = 3

f = (a > (b and c)) * (a) + (b> (a and c)) * (b) + (c > (a and b) ) * c

s = (c < a < b or b < a < c) * a + (a < c < b or b < c < a) * c + (a < b < c or c < b < a) * b 

t = (a < b and a < c ) * (a) + (b < a and b <  c) * (b) + (c < a and c < b ) * c

x = max(a,b,c)

y = min(a,b,c)

print(t, " ", s, " ", f)

print(y, " ", s, " ", x)
# Out:
# 1   2   3
# 1   2   3

# %% [markdown]
# Los operadores matematicos dan soluciones a problemas puntuales
